# %% [markdown]
# ## PPO-stable-baselines3 实现

# %%
from stable_baselines3 import A2C, PPO, SAC, TD3
from stable_baselines3.common.callbacks import BaseCallback
from gym.wrappers import TimeLimit
from stable_baselines3.common.env_checker import check_env
import gym

def run_train():
    env = gym.make('Walker2d-v2')
    env = TimeLimit(env, max_episode_steps=int(1e3))
    check_env(env)

    # define callback function
    class TensorboardCallback(BaseCallback):
        """
        Custom callback for plotting additional values in tensorboard.
        """
        def __init__(self, log_dir, verbose=0):
            super(TensorboardCallback, self).__init__(verbose)
            self.log_dir = log_dir

        def _on_step(self) -> bool:
            if self.n_calls % 51200 == 0:
                print("Saving new best model")
                self.model.save(self.log_dir + f"/model_saved/PPO/admit_diana_{self.n_calls}")
            return True

    log_dir = "log/"

    model = PPO(
        policy="MlpPolicy",
        env=env,
        verbose=1,
        tensorboard_log=log_dir,
        device="cuda:0",
    )
    # model = A2C.load("./log/model_saved/admit_diana_51200.zip")
    model.learn(total_timesteps=int(2e6), callback=TensorboardCallback(log_dir=log_dir))
    # model.save("admit_diana")
    obs = env.reset()
    ep_reward = 0
    for i in range(int(1e6)):
        action, _states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        ep_reward += reward
        if i % 2000 == 0 or done:
            env.reset()
            print(ep_reward)
            ep_reward = 0


run_train()
# Out:
# Using cuda:0 device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to log/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.6     |
# |    ep_rew_mean     | -0.527   |
# | time/              |          |
# |    fps             | 457      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 19.8     |
# |    ep_rew_mean          | 1.57     |
# | time/                   |          |
# |    fps                  | 384      |
# |    iterations           | 2        |
# |    time_elapsed         | 10       |
# |    total_timesteps      | 4096     |
# | train/                  |          |
# |    approx_kl            | 0.01872  |
# |    clip_fraction        | 0.262    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -8.51    |
# |    explained_variance   | -0.022   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.92     |
# |    n_updates            | 10       |
# |    policy_gradient_loss | -0.0376  |
# |    std                  | 0.999    |
# |    value_loss           | 9.73     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | 5.86        |
# | time/                   |             |
# |    fps                  | 370         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017611582 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.31        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.991       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.2        |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015794352 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.44       |
# |    explained_variance   | 0.151       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.65        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0339     |
# |    std                  | 0.984       |
# |    value_loss           | 16.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.1        |
# |    ep_rew_mean          | 18.3        |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012774151 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0276     |
# |    std                  | 0.981       |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 24.3        |
# | time/                   |             |
# |    fps                  | 349         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010791918 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.38       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.9        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.976       |
# |    value_loss           | 77.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.7        |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 348         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009977086 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.973       |
# |    value_loss           | 75.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.2         |
# |    ep_rew_mean          | 35.2         |
# | time/                   |              |
# |    fps                  | 342          |
# |    iterations           | 8            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0073677246 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.35        |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0131      |
# |    std                  | 0.972        |
# |    value_loss           | 70.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.9        |
# |    ep_rew_mean          | 42.5        |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 9           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007078762 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.34       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.97        |
# |    value_loss           | 75.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96           |
# |    ep_rew_mean          | 50.5         |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 10           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0059947814 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.33        |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0119      |
# |    std                  | 0.97         |
# |    value_loss           | 124          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 66          |
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 11          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007894478 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.32       |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.968       |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 74.5        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 12          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005235919 |
# |    clip_fraction        | 0.0241      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.31       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.1        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.966       |
# |    value_loss           | 157         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 144          |
# |    ep_rew_mean          | 87.4         |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 13           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0054765614 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.3         |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00935     |
# |    std                  | 0.964        |
# |    value_loss           | 175          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 99.7        |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 14          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006053618 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.29       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.964       |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 15          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007942725 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.3        |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.2        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.964       |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 337          |
# |    iterations           | 16           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0055696703 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.29        |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.6         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.962        |
# |    value_loss           | 179          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 17          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008379903 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.28       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.961       |
# |    value_loss           | 217         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 335         |
# |    iterations           | 18          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006536853 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.959       |
# |    value_loss           | 224         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 334          |
# |    iterations           | 19           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0076183043 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.26        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.3         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0138      |
# |    std                  | 0.959        |
# |    value_loss           | 153          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 182          |
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 20           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0066987462 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.26        |
# |    explained_variance   | 0.789        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 117          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0143      |
# |    std                  | 0.96         |
# |    value_loss           | 244          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 21          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010666511 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.959       |
# |    value_loss           | 222         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 22          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007364969 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.26       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.959       |
# |    value_loss           | 232         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 211         |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 23          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010301007 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.27       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0217     |
# |    std                  | 0.96        |
# |    value_loss           | 241         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 24          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008198494 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.25       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.954       |
# |    value_loss           | 196         |
# -----------------------------------------
# Saving new best model
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 25          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009637764 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.22       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 157         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.951       |
# |    value_loss           | 208         |
# -----------------------------------------
# /home/zhouhr/anaconda3/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'log/model_saved/PPO' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 26          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010342469 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.95        |
# |    value_loss           | 248         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 332         |
# |    iterations           | 27          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008893839 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.948       |
# |    value_loss           | 228         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 28          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010193394 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.632       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0188     |
# |    std                  | 0.951       |
# |    value_loss           | 318         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 29          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008400581 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.2        |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68          |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.948       |
# |    value_loss           | 295         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 30          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013520288 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.18       |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.945       |
# |    value_loss           | 327         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 31          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014980685 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.17       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.942       |
# |    value_loss           | 338         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 32          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009283965 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.14       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 203         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.938       |
# |    value_loss           | 368         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 204        |
# |    ep_rew_mean          | 269        |
# | time/                   |            |
# |    fps                  | 331        |
# |    iterations           | 33         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00979363 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.11      |
# |    explained_variance   | 0.672      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 177        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.021     |
# |    std                  | 0.935      |
# |    value_loss           | 300        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 34          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009803081 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.94        |
# |    value_loss           | 255         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 35          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009335116 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.13       |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 212         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.938       |
# |    value_loss           | 249         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 202         |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 36          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012360065 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.936       |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 37          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008546366 |
# |    clip_fraction        | 0.0846      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.11       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.935       |
# |    value_loss           | 128         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 198          |
# |    ep_rew_mean          | 281          |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 38           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0104975365 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.1         |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0218      |
# |    std                  | 0.931        |
# |    value_loss           | 75.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 281         |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 39          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011403916 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.08       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.932       |
# |    value_loss           | 77.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 198         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 40          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010006849 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.09       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.931       |
# |    value_loss           | 129         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 192        |
# |    ep_rew_mean          | 280        |
# | time/                   |            |
# |    fps                  | 328        |
# |    iterations           | 41         |
# |    time_elapsed         | 255        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01083797 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.08      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.1       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.023     |
# |    std                  | 0.93       |
# |    value_loss           | 46.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 189         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 42          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013443604 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.05       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0273     |
# |    std                  | 0.922       |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 43          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009551574 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.919       |
# |    value_loss           | 74.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 284         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 44          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010531668 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.96       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.909       |
# |    value_loss           | 44.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 288         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 45          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011551106 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.94       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.911       |
# |    value_loss           | 55.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 294         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 46          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012117811 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.907       |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 47          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010441649 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.909       |
# |    value_loss           | 49.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 301         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 48          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.012261539 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.93       |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.907       |
# |    value_loss           | 30.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 304         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 49          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013981536 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.89       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.028      |
# |    std                  | 0.9         |
# |    value_loss           | 34.4        |
# -----------------------------------------
# Saving new best model
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 304         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 50          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.012198129 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.85       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0258     |
# |    std                  | 0.896       |
# |    value_loss           | 41.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 299         |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 51          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011294791 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.83       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0267     |
# |    std                  | 0.892       |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 328         |
# |    iterations           | 52          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009887455 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.83       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0187     |
# |    std                  | 0.895       |
# |    value_loss           | 65          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# ...
# 331.985975756178
# 3357.972256262165
# 2982.5415462482238
# 980.0817370787075
# 1082.2084963268087
# 651.2027675864056
# 1372.220315633232
# 635.8235612740598
# 2846.4778742411777
# 53.268722412945614
# 916.5578496846408
# 1410.208095730469
# 1324.587722111039
# 1857.6158516763585
# 1358.6383358564424
# 1466.058240650593
# 1302.9014360152028
# 3416.771278263652
# 758.8063125838693
# 2613.7592232101124
# 1939.924076898584
# 2634.610699016136
# 3797.3288544316247
# 995.3378498220868
